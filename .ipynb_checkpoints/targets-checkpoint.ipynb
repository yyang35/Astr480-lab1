# %%
import matplotlib.pyplot as plt
from astropy.time import Time
from astroplan.plots import plot_airmass
from astroplan import FixedTarget, Observer
import pandas as pd
import numpy as np
import astropy.units as u
from astropy.coordinates import SkyCoord
import pytz
from astroplan import Observer, FixedTarget

# %%
df = pd.read_table("globular_cluster_list.txt",sep='|', index_col=False)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df
# Out:
#          name     alt_name           ra          dec   vmag  bv_color  \
# 0   Pal 1                   03 33 20.04  +79 34 51.8  13.18      0.96
# 1   NGC 6229                16 46 58.79  +47 31 39.9   9.39      0.70
# 2   NGC 6341   M 92         17 17 07.39  +43 08 09.4   6.44      0.63
# 3   NGC 2419                07 38 08.47  +38 52 56.8  10.41      0.66
# 4   NGC 6205   M 13         16 41 41.24  +36 27 35.5   5.78      0.68
# 5   Pal 2                   04 46 05.91  +31 22 53.4  13.04      2.08
# 6   NGC 6779   M 56         19 16 35.57  +30 11 00.5   8.27      0.86
# 7   Pal 4                   11 29 16.80  +28 58 24.9  14.20
# 8   NGC 5466                14 05 27.29  +28 32 04.0   9.04      0.67
# 9   NGC 5272   M 3          13 42 11.62  +28 22 38.2   6.19      0.69
# 10  Ko 2                    07 58 17.00  +26 15 18.0  17.60
# 11  NGC 6838   M 71         19 53 46.49  +18 46 45.1   8.19      1.09
# 12  Pal 10                  19 18 02.10  +18 34 18.0  13.22
# 13  NGC 4147                12 10 06.30  +18 32 33.5  10.32      0.59
# 14  NGC 5024   M 53         13 12 55.25  +18 10 05.4   7.61      0.64
# 15  NGC 5053                13 16 27.09  +17 42 00.9   9.47      0.65
# 16  NGC 7006                21 01 29.38  +16 11 14.4  10.56      0.75
# 17  Pal 14     AvdB         16 11 00.60  +14 57 28.0  14.74
# 18  Pal 13                  23 06 44.44  +12 46 19.2  13.47      0.76
# 19  Ko 1                    11 59 18.50  +12 15 36.0  17.10
# 20  NGC 7078   M 15         21 29 58.33  +12 10 01.2   6.20      0.68
# 21  NGC 6934                20 34 11.37  +07 24 16.1   8.83      0.77
# 22  NGC 6426                17 44 54.65  +03 10 12.5  11.01      1.02
# 23  NGC 5904   M 5          15 18 33.22  +02 04 51.7   5.65      0.72
# 24  NGC 6749                19 05 15.30  +01 54 03.0  12.44      2.14
# 25  NGC 6760                19 11 12.01  +01 01 49.7   8.88      1.66
# 26  Pal 3                   10 05 31.90  +00 04 18.0  14.26
# 27  Pal 5                   15 16 05.25  -00 06 41.8  11.75
# 28  NGC 6535                18 03 50.51  -00 17 51.5  10.47      0.94
# 29  Pal 15                  16 59 51.00  -00 32 20.0  14.00
# 30  NGC 7089   M 2          21 33 27.02  -00 49 23.7   6.47      0.66
# 31  GLIMPSE01               18 48 49.70  -01 29 50.0  22.24
# 32  NGC 6218   M 12         16 47 14.18  -01 56 54.7   6.70      0.83
# 33  NGC 6402   M 14         17 37 36.10  -03 14 45.3   7.59      1.25
# 34  Whiting 1               02 02 57.00  -03 15 10.0  15.03
# 35  NGC 6254   M 10         16 57 09.05  -04 06 01.1   6.60      0.90
# 36  NGC 6366                17 27 44.24  -05 04 47.5   9.20      1.44
# 37  NGC 5634                14 29 37.23  -05 58 35.1   9.47      0.67
# 38  IC 1257                 17 27 08.50  -07 05 35.0  13.10      1.38
# 39  IC 1276    Pal 7        18 10 44.20  -07 12 27.4  10.34      1.76
# 40  NGC 6539                18 04 49.68  -07 35 09.1   9.33      1.83
# 41  Pal 11                  19 45 14.40  -08 00 26.0   9.80      1.27
# 42  NGC 6712                18 53 04.30  -08 42 22.0   8.10      1.17
# 43  NGC 6517                18 01 50.52  -08 57 31.6  10.23      1.75
# 44  NGC 6981   M 72         20 53 27.70  -12 32 14.3   9.27      0.72
# 45  NGC 6171   M 107        16 32 31.86  -13 03 13.6   7.93      1.10
# 46  NGC 7492                23 08 26.63  -15 36 41.4  11.29      0.42
# 47  GLIMPSE02               18 18 30.50  -16 58 38.0
# 48  NGC 6356                17 23 34.93  -17 48 46.9   8.25      1.13
#
#     helio_distance  metallicity
# 0             11.1        -0.65
# 1             30.5        -1.47
# 2              8.3        -2.31
# 3             82.6        -2.15
# 4              7.1        -1.53
# 5             27.2        -1.42
# 6              9.4        -1.98
# 7            108.7        -1.41
# 8             16.0        -1.98
# 9             10.2        -1.50
# 10            34.7
# 11             4.0        -0.78
# 12             5.9        -0.10
# 13            19.3        -1.80
# 14            17.9        -2.10
# 15            17.4        -2.27
# 16            41.2        -1.52
# 17            76.5        -1.62
# 18            26.0        -1.88
# 19            48.3
# 20            10.4        -2.37
# 21            15.6        -1.47
# 22            20.6        -2.15
# 23             7.5        -1.29
# 24             7.9        -1.60
# 25             7.4        -0.40
# 26            92.5        -1.63
# 27            23.2        -1.41
# 28             6.8        -1.79
# 29            45.1        -2.07
# 30            11.5        -1.65
# 31             4.2
# 32             4.8        -1.37
# 33             9.3        -1.28
# 34            30.1        -0.70
# 35             4.4        -1.56
# 36             3.5        -0.59
# 37            25.2        -1.88
# 38            25.0        -1.70
# 39             5.4        -0.75
# 40             7.8        -0.63
# 41            13.4        -0.40
# 42             6.9        -1.02
# 43            10.6        -1.23
# 44            17.0        -1.42
# 45             6.4        -1.02
# 46            26.3        -1.78
# 47             5.5        -0.33
# 48            15.1        -0.40

# %%
from astroplan import ObservingBlock
from astroplan.constraints import TimeConstraint
from astropy import units as u
from astroplan.scheduling import Transitioner

mcdonald_observatory = Observer(longitude = -104.022 * u.deg,
                    latitude = 30.6714 * u.deg,
                    elevation = 2077 * u.m,
                    timezone = 'US/Central',
                    name = "McDonald Observatory"
                    )

# %%
reference_time = Time("2023-05-01")

# %%
astro_set = mcdonald_observatory.twilight_evening_astronomical(reference_time, which='nearest')
astro_rise = mcdonald_observatory.twilight_morning_astronomical(reference_time, which='next')
midnight_mro = mcdonald_observatory.midnight(reference_time, which='next')

# %%
midnight_mro
# Out:
# <Time object: scale='utc' format='jd' value=2460065.7868648614>

# %%
df['whether_up'] = False

# %%
for index, row in df.iterrows():
    coords = SkyCoord(row['ra'] + " " + row['dec'], frame="icrs", unit=(u.hourangle, u.deg))
    target = FixedTarget(name= row['name'], coord=coords)
    df.at[index,'whether_up'] = mcdonald_observatory.target_is_up(midnight_mro, target)

# %%
df = df[df['whether_up'] == True]
df = df.reset_index()

# %%
df
# Out:
#     index       name     alt_name           ra          dec  vmag   bv_color  \
# 0       0  Pal 1                   03 33 20.04  +79 34 51.8  13.18      0.96
# 1       1  NGC 6229                16 46 58.79  +47 31 39.9   9.39      0.70
# 2       2  NGC 6341   M 92         17 17 07.39  +43 08 09.4   6.44      0.63
# 3       3  NGC 2419                07 38 08.47  +38 52 56.8  10.41      0.66
# 4       4  NGC 6205   M 13         16 41 41.24  +36 27 35.5   5.78      0.68
# 5       6  NGC 6779   M 56         19 16 35.57  +30 11 00.5   8.27      0.86
# 6       7  Pal 4                   11 29 16.80  +28 58 24.9  14.20
# 7       8  NGC 5466                14 05 27.29  +28 32 04.0   9.04      0.67
# 8       9  NGC 5272   M 3          13 42 11.62  +28 22 38.2   6.19      0.69
# 9      10  Ko 2                    07 58 17.00  +26 15 18.0  17.60
# 10     11  NGC 6838   M 71         19 53 46.49  +18 46 45.1   8.19      1.09
# 11     12  Pal 10                  19 18 02.10  +18 34 18.0  13.22
# 12     13  NGC 4147                12 10 06.30  +18 32 33.5  10.32      0.59
# 13     14  NGC 5024   M 53         13 12 55.25  +18 10 05.4   7.61      0.64
# 14     15  NGC 5053                13 16 27.09  +17 42 00.9   9.47      0.65
# 15     16  NGC 7006                21 01 29.38  +16 11 14.4  10.56      0.75
# 16     17  Pal 14     AvdB         16 11 00.60  +14 57 28.0  14.74
# 17     19  Ko 1                    11 59 18.50  +12 15 36.0  17.10
# 18     21  NGC 6934                20 34 11.37  +07 24 16.1   8.83      0.77
# 19     22  NGC 6426                17 44 54.65  +03 10 12.5  11.01      1.02
# 20     23  NGC 5904   M 5          15 18 33.22  +02 04 51.7   5.65      0.72
# 21     24  NGC 6749                19 05 15.30  +01 54 03.0  12.44      2.14
# 22     25  NGC 6760                19 11 12.01  +01 01 49.7   8.88      1.66
# 23     26  Pal 3                   10 05 31.90  +00 04 18.0  14.26
# 24     27  Pal 5                   15 16 05.25  -00 06 41.8  11.75
# 25     28  NGC 6535                18 03 50.51  -00 17 51.5  10.47      0.94
# 26     29  Pal 15                  16 59 51.00  -00 32 20.0  14.00
# 27     31  GLIMPSE01               18 48 49.70  -01 29 50.0  22.24
# 28     32  NGC 6218   M 12         16 47 14.18  -01 56 54.7   6.70      0.83
# 29     33  NGC 6402   M 14         17 37 36.10  -03 14 45.3   7.59      1.25
# 30     35  NGC 6254   M 10         16 57 09.05  -04 06 01.1   6.60      0.90
# 31     36  NGC 6366                17 27 44.24  -05 04 47.5   9.20      1.44
# 32     37  NGC 5634                14 29 37.23  -05 58 35.1   9.47      0.67
# 33     38  IC 1257                 17 27 08.50  -07 05 35.0  13.10      1.38
# 34     39  IC 1276    Pal 7        18 10 44.20  -07 12 27.4  10.34      1.76
# 35     40  NGC 6539                18 04 49.68  -07 35 09.1   9.33      1.83
# 36     41  Pal 11                  19 45 14.40  -08 00 26.0   9.80      1.27
# 37     42  NGC 6712                18 53 04.30  -08 42 22.0   8.10      1.17
# 38     43  NGC 6517                18 01 50.52  -08 57 31.6  10.23      1.75
# 39     45  NGC 6171   M 107        16 32 31.86  -13 03 13.6   7.93      1.10
# 40     47  GLIMPSE02               18 18 30.50  -16 58 38.0
# 41     48  NGC 6356                17 23 34.93  -17 48 46.9   8.25      1.13
#
#     helio_distance  metallicity  whether_up
# 0             11.1        -0.65        True
# 1             30.5        -1.47        True
# 2              8.3        -2.31        True
# 3             82.6        -2.15        True
# 4              7.1        -1.53        True
# 5              9.4        -1.98        True
# 6            108.7        -1.41        True
# 7             16.0        -1.98        True
# 8             10.2        -1.50        True
# 9             34.7                     True
# 10             4.0        -0.78        True
# 11             5.9        -0.10        True
# 12            19.3        -1.80        True
# 13            17.9        -2.10        True
# 14            17.4        -2.27        True
# 15            41.2        -1.52        True
# 16            76.5        -1.62        True
# 17            48.3                     True
# 18            15.6        -1.47        True
# 19            20.6        -2.15        True
# 20             7.5        -1.29        True
# 21             7.9        -1.60        True
# 22             7.4        -0.40        True
# 23            92.5        -1.63        True
# 24            23.2        -1.41        True
# 25             6.8        -1.79        True
# 26            45.1        -2.07        True
# 27             4.2                     True
# 28             4.8        -1.37        True
# 29             9.3        -1.28        True
# 30             4.4        -1.56        True
# 31             3.5        -0.59        True
# 32            25.2        -1.88        True
# 33            25.0        -1.70        True
# 34             5.4        -0.75        True
# 35             7.8        -0.63        True
# 36            13.4        -0.40        True
# 37             6.9        -1.02        True
# 38            10.6        -1.23        True
# 39             6.4        -1.02        True
# 40             5.5        -0.33        True
# 41            15.1        -0.40        True

# %%
from astroplan.plots import plot_sky
import matplotlib.pyplot as plt
from astroplan import time_grid_from_range

start_time = astro_set
end_time = astro_rise

observing_range = [astro_set, astro_rise]
time_grid = time_grid_from_range(observing_range)

# %%
df.head()
# Out:
#         name     alt_name           ra          dec   vmag  bv_color  \
# 0  Pal 1                   03 33 20.04  +79 34 51.8  13.18      0.96
# 1  NGC 6229                16 46 58.79  +47 31 39.9   9.39      0.70
# 2  NGC 6341   M 92         17 17 07.39  +43 08 09.4   6.44      0.63
# 3  NGC 2419                07 38 08.47  +38 52 56.8  10.41      0.66
# 4  NGC 6205   M 13         16 41 41.24  +36 27 35.5   5.78      0.68
#
#    helio_distance  metallicity
# 0            11.1        -0.65
# 1            30.5        -1.47
# 2             8.3        -2.31
# 3            82.6        -2.15
# 4             7.1        -1.53

# %%
fig = plt.figure()
for index, row in df[0:10].iterrows():
    print(index)
    coords = SkyCoord(row['ra'] + " " + row['dec'], frame="icrs", unit=(u.hourangle, u.deg))
    target = FixedTarget(name= row['name'], coord=coords)
    
    ax = plot_sky(target, mcdonald_observatory, observe_time) 
    ax.plot(label= row['name'])
    
ax.legend(bbox_to_anchor=(1.1, 1.05))
plt.show()
plt.savefig('1.png')
# Out:
# 0
# /opt/conda/lib/python3.9/site-packages/astroplan/plots/sky.py:120: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = plt.gca(projection='polar')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_145/1192840715.py in <module>
#       4     coords = SkyCoord(row['ra'] + " " + row['dec'], frame="icrs", unit=(u.hourangle, u.deg))
#       5     target = FixedTarget(name= row['name'], coord=coords)
# ----> 6     ax = plot_sky(target, mcdonald_observatory, observe_time)
#       7     ax.plot(label= row['name'])
#       8
#
# /opt/conda/lib/python3.9/site-packages/astropy/units/decorators.py in wrapper(*func_args, **func_kwargs)
#     251             # Call the original function with any equivalencies in force.
#     252             with add_enabled_equivalencies(self.equivalencies):
# --> 253                 return_ = wrapped_function(*func_args, **func_kwargs)
#     254
#     255             valid_empty = (inspect.Signature.empty, None)
#
# /opt/conda/lib/python3.9/site-packages/astroplan/plots/sky.py in plot_sky(target, observer, time, ax, style_kwargs, north_to_east_ccw, grid, az_label_offset, warn_below_horizon, style_sheet)
#     132     # Note that values must be made dimensionless before plotting.
#     133     # Modifying altitude is easier than inverting r-axis.
# --> 134     altitude = (91 * u.deg - observer.altaz(time, target).alt) * (1/u.deg)
#     135     # Azimuth MUST be given to plot() in radians.
#     136     azimuth = observer.altaz(time, target).az * (1/u.deg) * (np.pi/180.0)
#
# /opt/conda/lib/python3.9/site-packages/astroplan/observer.py in altaz(self, time, target, obswl, grid_times_targets)
#     495             return altaz_frame
#     496         else:
# --> 497             return target.transform_to(altaz_frame)
#     498
#     499     def parallactic_angle(self, time, target, grid_times_targets=False):
#
# /opt/conda/lib/python3.9/site-packages/astropy/coordinates/sky_coordinate.py in transform_to(self, frame, merge_attributes)
#     656         # Do the transformation, returning a coordinate frame of the desired
#     657         # final type (not generic).
# --> 658         new_coord = trans(self.frame, generic_frame)
#     659
#     660         # Finally make the new SkyCoord object from the `new_coord` and
#
# /opt/conda/lib/python3.9/site-packages/astropy/coordinates/transformations.py in __call__(self, fromcoord, toframe)
#    1420
#    1421             curr_toframe = t.tosys(**frattrs)
# -> 1422             curr_coord = t(curr_coord, curr_toframe)
#    1423
#    1424         # this is safe even in the case where self.transforms is empty, because
#
# /opt/conda/lib/python3.9/site-packages/astropy/coordinates/transformations.py in __call__(self, fromcoord, toframe)
#    1023             return reprwithoutdiff.realize_frame(reprwithdiff)
#    1024         else:
# -> 1025             return supcall(fromcoord, toframe)
#    1026
#    1027
#
# /opt/conda/lib/python3.9/site-packages/astropy/coordinates/builtin_frames/icrs_observed_transforms.py in icrs_to_altaz(icrs_coo, altaz_frame)
#      38
#      39     # convert to topocentric CIRS
# ---> 40     cirs_ra, cirs_dec = atciqz(srepr, astrom)
#      41
#      42     # now perform AltAz conversion
#
# /opt/conda/lib/python3.9/site-packages/astropy/coordinates/builtin_frames/utils.py in atciqz(srepr, astrom)
#     295
#     296     # BCRS coordinate direction (unit vector).
# --> 297     pco = erfa.s2c(srepr.lon.radian, srepr.lat.radian)
#     298
#     299     # Find BCRS direction of Sun to object
#
# /opt/conda/lib/python3.9/site-packages/astropy/units/quantity.py in __getattr__(self, attr)
#     864
#     865         if value is None:
# --> 866             raise AttributeError(
#     867                 f"{self.__class__.__name__} instance has no attribute '{attr}'")
#     868         else:
#
# AttributeError: Longitude instance has no attribute 'radian'

# %%
observe_time = midnight_mro + np.linspace(-10, 10, 20)*u.hour
this_room = Observer(longitude = -104.022 * u.deg,
                    latitude = 30.6714 * u.deg,
                    elevation = 2077 * u.m,
                    timezone = 'US/Pacific',
                    name = "Computer Lab"
                    )

fig = plt.figure()
for index, row in df[0:10].iterrows():
    coords = SkyCoord(row['ra'] + " " + row['dec'], frame="icrs", unit=(u.hourangle, u.deg))
    target = FixedTarget(name= row['name'], coord=coords)
    ax = plot_sky(target, this_room, observe_time)
    ax.plot(label= row['name'])
    
ax.legend(bbox_to_anchor=(1.1, 1.05))
plt.show()
plt.savefig('1.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_145/2424154021.py in <module>
#      11     coords = SkyCoord(row['ra'] + " " + row['dec'], frame="icrs", unit=(u.hourangle, u.deg))
#      12     target = FixedTarget(name= row['name'], coord=coords)
# ---> 13     ax = plot_sky(target, this_room, observe_time)
#      14     ax.plot(label= row['name'])
#      15
#
# /opt/conda/lib/python3.9/site-packages/astropy/units/decorators.py in wrapper(*func_args, **func_kwargs)
#     251             # Call the original function with any equivalencies in force.
#     252             with add_enabled_equivalencies(self.equivalencies):
# --> 253                 return_ = wrapped_function(*func_args, **func_kwargs)
#     254
#     255             valid_empty = (inspect.Signature.empty, None)
#
# /opt/conda/lib/python3.9/site-packages/astroplan/plots/sky.py in plot_sky(target, observer, time, ax, style_kwargs, north_to_east_ccw, grid, az_label_offset, warn_below_horizon, style_sheet)
#     132     # Note that values must be made dimensionless before plotting.
#     133     # Modifying altitude is easier than inverting r-axis.
# --> 134     altitude = (91 * u.deg - observer.altaz(time, target).alt) * (1/u.deg)
#     135     # Azimuth MUST be given to plot() in radians.
#     136     azimuth = observer.altaz(time, target).az * (1/u.deg) * (np.pi/180.0)
#
# /opt/conda/lib/python3.9/site-packages/astroplan/observer.py in altaz(self, time, target, obswl, grid_times_targets)
#     495             return altaz_frame
#     496         else:
# --> 497             return target.transform_to(altaz_frame)
#     498
#     499     def parallactic_angle(self, time, target, grid_times_targets=False):
#
# /opt/conda/lib/python3.9/site-packages/astropy/coordinates/sky_coordinate.py in transform_to(self, frame, merge_attributes)
#     656         # Do the transformation, returning a coordinate frame of the desired
#     657         # final type (not generic).
# --> 658         new_coord = trans(self.frame, generic_frame)
#     659
#     660         # Finally make the new SkyCoord object from the `new_coord` and
#
# /opt/conda/lib/python3.9/site-packages/astropy/coordinates/transformations.py in __call__(self, fromcoord, toframe)
#    1420
#    1421             curr_toframe = t.tosys(**frattrs)
# -> 1422             curr_coord = t(curr_coord, curr_toframe)
#    1423
#    1424         # this is safe even in the case where self.transforms is empty, because
#
# /opt/conda/lib/python3.9/site-packages/astropy/coordinates/transformations.py in __call__(self, fromcoord, toframe)
#    1023             return reprwithoutdiff.realize_frame(reprwithdiff)
#    1024         else:
# -> 1025             return supcall(fromcoord, toframe)
#    1026
#    1027
#
# /opt/conda/lib/python3.9/site-packages/astropy/coordinates/builtin_frames/icrs_observed_transforms.py in icrs_to_altaz(icrs_coo, altaz_frame)
#      38
#      39     # convert to topocentric CIRS
# ---> 40     cirs_ra, cirs_dec = atciqz(srepr, astrom)
#      41
#      42     # now perform AltAz conversion
#
# /opt/conda/lib/python3.9/site-packages/astropy/coordinates/builtin_frames/utils.py in atciqz(srepr, astrom)
#     295
#     296     # BCRS coordinate direction (unit vector).
# --> 297     pco = erfa.s2c(srepr.lon.radian, srepr.lat.radian)
#     298
#     299     # Find BCRS direction of Sun to object
#
# /opt/conda/lib/python3.9/site-packages/astropy/units/quantity.py in __getattr__(self, attr)
#     864
#     865         if value is None:
# --> 866             raise AttributeError(
#     867                 f"{self.__class__.__name__} instance has no attribute '{attr}'")
#     868         else:
#
# AttributeError: Longitude instance has no attribute 'radian'

# %%
# Out:
# str

# %%
for index, row in df[10:20].iterrows():
    coords = SkyCoord(row['ra'] + " " + row['dec'], frame="icrs", unit=(u.hourangle, u.deg))
    target = FixedTarget(name= row['name'], coord=coords)
    ax = plot_sky(target, this_room, observe_time)
    ax.plot(label= row['name'])
    
ax.legend(bbox_to_anchor=(1.1, 1.05))
plt.show()
plt.savefig('2.png')

# %%
for index, row in df[20:30].iterrows():
    coords = SkyCoord(row['ra'] + " " + row['dec'], frame="icrs", unit=(u.hourangle, u.deg))
    target = FixedTarget(name= row['name'], coord=coords)
    ax = plot_sky(target, this_room, observe_time)
    ax.plot(label= row['name'])
    
ax.legend(bbox_to_anchor=(1.1, 1.05))
plt.show()
plt.savefig('3.png')

# %%
for index, row in df[30:40].iterrows():
    coords = SkyCoord(row['ra'] + " " + row['dec'], frame="icrs", unit=(u.hourangle, u.deg))
    target = FixedTarget(name= row['name'], coord=coords)
    ax = plot_sky(target, this_room, observe_time)
    ax.plot(label= row['name'])
    
ax.legend(bbox_to_anchor=(1.1, 1.05))
plt.show()
plt.savefig('4.png')

# %%
for index, row in df[40:48].iterrows():
    coords = SkyCoord(row['ra'] + " " + row['dec'], frame="icrs", unit=(u.hourangle, u.deg))
    target = FixedTarget(name= row['name'], coord=coords)
    ax = plot_sky(target, this_room, observe_time)
    ax.plot(label= row['name'])
    
ax.legend(bbox_to_anchor=(1.1, 1.05))
plt.show()
plt.savefig('5.png')

# %%
fig = plt.figure()

for index, row in df2.iterrows():
    coords = SkyCoord(row['ra'] + " " + row['dec'], frame="icrs", unit=(u.hourangle, u.deg))
    target = FixedTarget(name= row['name'], coord=coords)
    ax = plot_sky(target, this_room, observe_time)
    ax.plot(label= row['name'])
    
ax.legend(bbox_to_anchor=(1.1, 1.05))
plt.show()
